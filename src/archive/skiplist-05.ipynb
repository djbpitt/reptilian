# %%
# %load_ext autoreload
# %autoreload 2

import pprint, typing
pp = pprint.PrettyPrinter(indent=2)

# %%
# %run create-blocks.ipynb # data will be in prioritized_blocks
# pp.pprint(prioritized_blocks) # take a look
# pp.pprint(token_to_block_dict) # and another look
# print(token_array, len(token_array)) # and one more look

# %% [markdown]
# # Skiplist of variant graph nodes kept in a partial order
#
# Keys are variant graph nodes. Values are not really relevant, but for now they are offsets into the witnesses.
# The floor and ceiling should contain not only the siglum of the token we want to insert but also of another witness.
# The different methods in the skiplist should no longer try and catch partial order exceptions. Instead filters should be passed along before an insert-and-find operation next to a comparator function so that comparison never fails.
#
# There are two lookups, which happen in the following order:
#
# 1. To see whether a token has already been inserted, look only at tokens with the siglum we are processing. For example, if we are placing a token for `w0`, we look at nodes that contain tokens for `w0` (regardless of whether other witnesses are also present on them). If our token is already there, break. We can implement this as a bitarray the length of the `token_array`, initialized to all False.
# 1. If the token has not already been placed, we next look for a floor and ceiling in order to insert the token. In this case, we look only at nodes that have both of the following properties: a) then contain a token for the witness we are trying to place, and b) they contain tokens for a total of two or more witnesses, that is, at least one witness in addition to the one on which we are focused. For the example above, if we reach this stage, floor and ceiling candidates must contain `w0` and a total of at least 2 sigla. The comparator should not raise an exception except if there is an actual error in the comparison logic (that is, unlike our earlier try/catch approach).
#
# We control step 2 with filters, which we pass to the comparator functions.

# %%
#
# This file is part of Bluepass. Bluepass is Copyright (c) 2012-2014
# Geert Jansen.
#
# Bluepass is free software available under the GNU General Public License,
# version 3. See the file LICENSE distributed with this file for the exact
# licensing terms.

from __future__ import absolute_import, print_function

import os
import sys
import math
import random

__all__ = ['SkipList']


# The following functions are debugging functions. They are available only when
# Python is not started with -O.

if __debug__:

    def fmtnode(node):
        """Format a single skiplist node."""
        level = max(1, len(node) - 3)
        skip = '(none)' if level == 1 else node[-1]
        return '<Node(level={}, key={}, value={}, skip={})>' \
                    .format(level, node[0], node[1], skip)

    def dump(sl, file=sys.stdout):
        """Dump a skiplist to standard output."""
        print('== Dumping skiplist {0!r}'.format(sl), file=file)
        print('Level: {}/{}'.format(sl.level, sl.maxlevel), file=file)
        print('Size: {}'.format(len(sl)), file=file)
        node = sl._head
        print('{0} (head)'.format(fmtnode(node)), file=file)
        node = node[2]
        avglvl = avglen = avgsiz = 0
        while node is not sl._tail:
            print('{0}'.format(fmtnode(node)), file=file)
            node = node[2]
            avglvl += max(1, len(node) - 3)
            avglen += len(node)
            avgsiz += nodesize(node)
        print('{0} (tail)'.format(fmtnode(node)), file=file)
        print('Avg level: {:.2f}'.format(avglvl/len(sl)), file=file)
        print('Avg node len: {:.2f}'.format(avglen/len(sl)), file=file)
        print('Avg node memory: {:.2f}'.format(avgsiz/len(sl)), file=file)
        print(file=file)

    def check(sl):
        """Check the internal structure of a skiplist."""
        level = sl.maxlevel
        assert level > 0
        while sl._head[1+level] is sl._tail and level > 1:
            level -= 1
        assert level == sl.level
        assert sl._head[0] is sl._head[1] is None
        assert sl._head[-1] == 0
        pos = 0
        node = sl._head
        inbound = {id(sl._head): 0, id(sl._tail): len(sl)}
        while node is not sl._tail:
            assert isinstance(node, list)
            level = min(sl.level, max(1, len(node)-3))
            assert 1 <= level <= sl.maxlevel
            for i in range(1, level):
                fnode = node[2+i]
                flevel = min(sl.level, max(1, len(fnode)-3))
                if i == flevel-1:
                    inbound[id(fnode)] = pos
            if level > 1:
                assert id(node) in inbound
                assert pos == inbound[id(node)] + node[-1]
            for i in range(level):
                fnode = node[2+i]
                assert isinstance(fnode, list)
                level = max(1, len(node) - 3)
                assert level >= i+1
            node = node[2]
            pos += 1
        assert sl._tail[0] is None
        assert sl._tail[1] is None
        for i in range(sl.maxlevel):
            assert sl._tail[2+i] is None
        assert len(sl) == inbound[id(sl._tail)] + node[-1]

    def nodesize(node):
        """Return the size of a skiplist node."""
        size = sys.getsizeof(node)
        size += sys.getsizeof(node[0])
        size += sys.getsizeof(node[1])
        # All elements in [3:-1] are references so don't count
        if len(node) > 3:
            size += sys.getsizeof(node[-1])
        return size

    def getsize(sl):
        """Return total size of a skiplist."""
        size = sys.getsizeof(sl)
        size += sys.getsizeof(sl._level)
        node = sl._head
        while node is not sl._tail:
            size += nodesize(node)
            node = node[2]
        size += nodesize(node)
        size += sys.getsizeof(sl._path)  # contains references or None
        size += sys.getsizeof(sl._distance)
        for el in sl._distance:
            size += sys.getsizeof(el)
        return size


class SkipList(object):
    """An indexable skip list.

    A SkipList provides an ordered sequence of key-value pairs. The list is
    always sorted on key and supports O(1) forward iteration. It has O(log N)
    time complexity for key lookup, pair insertion and pair removal anywhere in
    the list. The list also supports O(log N) element access by position.

    The keys of all pairs you add to the skiplist must be be comparable against
    each other, and define the ``<`` and ``<=`` operators.
    """

    UNSET = object()

    p = int((1<<31) / math.e)
    maxlevel = 20

    # Kudos to http://pythonsweetness.tumblr.com/post/45227295342 for some
    # useful tricks, including using a list for the nodes to save memory.

    # Use the built-in Mersenne Twister random number generator. It is more
    # appropriate than SystemRandom because we don't need cryptographically
    # secure random numbers, and we don't want to do a system call to read
    # /dev/urandom for each random number we need (every insertion needs a new
    # random number).

    _rnd = random.Random()
    _rnd.seed(os.urandom(16))

    __slots__ = ('_level', '_head', '_tail', '_path', '_distance', '_last_comparable_node_higher')

#####
# Add _last-comparable_node property in __init__(); needed for floor() and 
# ceiling() (add to __slots__, too)
#####
    def __init__(self):
        self._level = 1
        self._head = self._new_node(self.maxlevel, None, None)
        self._tail = self._new_node(self.maxlevel, None, None)
        for i in range(self.maxlevel):
            self._head[2+i] = self._tail
        self._path = [None] * self.maxlevel
        self._distance = [None] * self.maxlevel

    def _new_node(self, level, key, value):
        # Node layout: [key, value, next*LEVEL, skip?]
        # The "skip" element indicates how many nodes are skipped by the
        # highest level incoming link.
        if level == 1:
            return [key, value, None]
        else:
            return [key, value] + [None]*level + [0]

    def _random_level(self):
        # Exponential distribution as per Pugh's paper.
        l = 1
        maxlevel = min(self.maxlevel, self.level+1)
        while l < maxlevel and self._rnd.getrandbits(31) < self.p:
            l += 1
        return l

    def _create_node(self, key, value):
        # Create a new node, updating the list level if required.
        level = self._random_level()
        if level > self.level:
            self._tail[-1] = len(self)
            self._level = level
            self._path[level-1] = self._head
            self._distance[level-1] = 0
        return self._new_node(level, key, value)

    def _find_lt(self, key, skiplist_filter: typing.Callable= lambda x: True):
        # Find path to last node < key
        node = self._head
        distance = 0
        for i in reversed(range(self.level)):
#####
# Keys are partially ordered, so if two are not comparable (because they
# share no sigla), the comparator in S_Key will raise a ComparisonError,
# which we'll trap and then skip to the next key)
#
# We add and use last_comparable_node for our floor() and ceiling(), so
# that we don't return a node that is unordered with respect to the one we
# are querying
#
# Same modification in _find_lt() and _find_lte()
#####
            nnode = node[2+i]
            while nnode is not self._tail:
                true_or_false = skiplist_filter(nnode[0])
                if true_or_false:
                    if nnode[0] < key:
                        nnode, node = nnode[2+i], nnode
                        distance += 1 if i == 0 else node[-1]
                        last_comparable_node = node
                    else:
                        break
                else:
                    nnode = nnode[2+i]
                    continue
            self._path[i] = node
            self._distance[i] = distance
        self._last_comparable_node_higher = nnode

    def _find_lte(self, key: str, skiplist_filter: typing.Callable= lambda x: True):
        # TODO: update all calls to this function in include new skiplist_filter
        #   parameter and remove default value
        # Find path to last node <= key
        node = self._head
        distance = 0
        for i in reversed(range(self.level)):
            nnode = node[2+i] # next node
            while nnode is not self._tail:
                # we call the skiplist_filter on the next node
                true_or_false = skiplist_filter(nnode[0])
                if true_or_false:
                    if nnode[0] <= key:
                        nnode, node = nnode[2+i], nnode # move to next node on same level
                        distance += 1 if i == 0 else node[-1] # wtf
                        last_comparable_node = node # last node to pass through filter
                    else:
                        break # break out of while loop, up to for loop (to lower level in skiplist)
                else: # node did not satisfy filter; keep current node and set next node to actual next-next node
                    nnode = nnode[2+i]
                    continue
            # change state of three fields instead of return:
            #   path, distance, last comparable node higher
            #   which one we use depends on caller
            self._path[i] = node # track node visited on each level; equals last node lte target
            self._distance[i] = distance
        self._last_comparable_node_higher = nnode

    def _find_pos(self, pos):
        # Create path to node at pos.
        node = self._head
        distance = 0
        for i in reversed(range(self.level)):
            nnode = node[2+i]
            ndistance = distance + (1 if i == 0 else nnode[-1])
            while nnode is not self._tail and ndistance <= pos:
                nnode, node, distance = nnode[2+i], nnode, ndistance
                ndistance += 1 if i == 0 else nnode[-1]
            self._path[i] = node
            self._distance[i] = distance

    def _insert(self, node):
        # Insert a node in the list. The _path and _distance must be set.
        path, distance = self._path, self._distance
        # Update pointers
        level = max(1, len(node) - 3)
        for i in range(level):
            node[2+i] = path[i][2+i]
            path[i][2+i] = node
        if level > 1:
            node[-1] = 1 + distance[0] - distance[level-1]
        # Update skip counts
        node = node[2]
        i = 2; j = min(len(node) - 3, self.level)
        while i <= self.level:
            while j < i:
                node = node[i]
                j = min(len(node) - 3, self.level)
            node[-1] -= distance[0] - distance[j-1] if j <= level else -1
            i = j+1

    def _remove(self, node):
        # Remove a node. The _path and _distance must be set.
        path, distance = self._path, self._distance
        level = max(1, len(node) - 3)
        for i in range(level):
            path[i][2+i] = node[2+i]
        # Update skip counts
        value = node[1]
        node = node[2]
        i = 2; j = min(len(node) - 3, self.level)
        while i <= self.level:
            while j < i:
                node = node[i]
                j = min(len(node) - 3, self.level)
            node[-1] += distance[0] - distance[j-1] if j <= level else -1
            i = j+1
        # Reduce level if last node on current level was removed
        while self.level > 1 and self._head[1+self.level] is self._tail:
            self._level -= 1
            self._tail[-1] += self._tail[-1] - len(self)
        return value

    # PUBLIC API ...

    @property
    def level(self):
        """The current level of the skip list."""
        return self._level

    def insert(self, key, value, siglum_filter: typing.Callable = lambda x: True):
        """Insert a key-value pair in the list.

        The pair is inserted at the correct location so that the list remains
        sorted on *key*. If a pair with the same key is already in the list,
        then the pair is appended after all other pairs with that key.
        """
        self._find_lte(key, siglum_filter)
        node = self._create_node(key, value)
        self._insert(node)

    def replace(self, key, value):
        """Replace the value of the first key-value pair with key *key*.

        If the key was not found, the pair is inserted.
        """
        self._find_lt(key)
        node = self._last_comparable_node_higher
        if node is self._tail or key < node[0]:
            node = self._create_node(key, value)
            self._insert(node)
        else:
            node[1] = value

    def clear(self):
        """Remove all key-value pairs."""
        for i in range(self.maxlevel):
            self._head[2+i] = self._tail
            self._tail[-1] = 0
        self._level = 1

    def __len__(self):
        """Return the number of pairs in the list."""
        dist = 0
        idx = self.level + 1
        node = self._head[idx]
        while node is not self._tail:
            dist += node[-1] if idx > 2 else 1
            node = node[idx]
        dist += node[-1]
        return dist

    __bool__ = __nonzero__ = lambda self: len(self) > 0

    def __repr__(self):
        return type(self).__name__ + '((' + repr(list(self.items()))[1:-1] + '))'

    def items(self, start=None, stop=None, start_filter=None, stop_filter=None):
        """Return an iterator yielding pairs.

        If *start* is specified, iteration starts at the first pair with a key
        that is larger than or equal to *start*. If not specified, iteration
        starts at the first pair in the list.

        If *stop* is specified, iteration stops at the last pair that is
        smaller than *stop*. If not specified, iteration end with the last pair
        in the list.
        """
        if start is None:
            node = self._head[2]
        else:
            self._find_lt(start, start_filter)
            node = self._last_comparable_node_higher
        # while node is not self._tail and (stop is None or stop_filter(node[0]) and node[0] < stop):

        # If we reach the tail, we stop
        # Otherwise, does the node pass the stop filter
        # If we get that far, we can check whether the node is less than the stop value …
        #     … and. if it is, we yield
        # If we don't get that far, we advance to the next node and continue the while loop
        while node is not self._tail:
            yield (node[0], node[1])
            if stop and stop_filter(node[0]):
                if node[0] < stop:
                    node = node[2]
                    continue
                else:
                    break
            node = node[2]

    __iter__ = items

    def keys(self, start=None, stop=None):
        """Like :meth:`items` but returns only the keys."""
        return (item[0] for item in self.items(start, stop))

    def values(self, start=None, stop=None):
        """Like :meth:`items` but returns only the values."""
        return (item[1] for item in self.items(start, stop))

    def popitem(self):
        """Removes the first key-value pair and return it.

        This method raises a ``KeyError`` if the list is empty.
        """
        node = self._head[2]
        if node is self._tail:
            raise KeyError('list is empty')
        self._find_lt(node[0])
        self._remove(node)
        return (node[0], node[1])

    # BY KEY API ...

    def search(self, key, default=None):
        """Find the first key-value pair with key *key* and return its value.

        If the key was not found, return *default*. If no default was provided,
        return ``None``. This method never raises a ``KeyError``.
        """
        self._find_lt(key)
        node = self._last_comparable_node_higher
        if node is self._tail or key < node[0]:
            return default
        return node[1]

    def remove(self, key, siglum_filter: typing.Callable = lambda x: True):
        """Remove the first key-value pair with key *key*.

        If the key was not found, a ``KeyError`` is raised.
        """
        self._find_lt(key, siglum_filter)
        node = self._last_comparable_node_higher
        if node is self._tail or key < node[0]:
            raise KeyError('{!r} is not in list'.format(key))
        self._remove(node)

    def pop(self, key, default=UNSET):
        """Remove the first key-value pair with key *key*.

        If a pair was removed, return its value. Otherwise if *default* was
        provided, return *default*. Otherwise a ``KeyError`` is raised.
        """
        self._find_lt(key)
        node = self._last_comparable_node_higher
        if node is self._tail or key < node[0]:
            if default is self.UNSET:
                raise KeyError('key {!r} not in list')
            return default
        self._remove(node)
        return node[1]

    def __contains__(self, key):
        """Return whether *key* is contained in the list."""
        self._find_lt(key)
        node = self._last_comparable_node_higher
        return node is not self._tail and not key < node[0]

    def index(self, key, default=UNSET):
        """Find the first key-value pair with key *key* and return its position.

        If the key is not found, return *default*. If default was not provided,
        raise a ``KeyError``
        """
        self._find_lt(key)
        node = self._last_comparable_node_higher
        if node is self._tail or key < node[0]:
            if default is self.UNSET:
                raise KeyError('key {!r} not in list'.format(key))
            return default
        return self._distance[0]

    def count(self, key):
        """Return the number of pairs with key *key*."""
        count = 0
        pos = self.index(key, -1)
        if pos == -1:
            return count
        count += 1
        for i in range(pos+1, len(self)):
            if self[i][0] != key:
                break
            count += 1
        return count

    # BY POSITION API ...

    def __getitem__(self, pos):
        """Return a pair by its position.

        If *pos* is a slice, then return a generator that yields pairs as
        specified by the slice.
        """
        size = len(self)
        if isinstance(pos, int):
            if pos < 0:
                pos += size
            if not 0 <= pos < size:
                raise IndexError('list index out of range')
            self._find_pos(pos)
            node = self._path[0][2]
            return (node[0], node[1])
        elif isinstance(pos, slice):
            start, stop = pos.start, pos.stop
            if start is None:
                start = 0
            elif start < 0:
                start += size
            if stop is None:
                stop = size
            elif stop < 0:
                stop += size
            self._find_pos(start)
            def genpairs():
                pos = start; node = self._path[0][2]
                while node is not self._tail and pos < stop:
                    yield (node[0], node[1])
                    node = node[2]; pos += 1
            return genpairs()
        else:
            raise TypeError('expecting int or slice, got {0.__name__!r}'.format(type(pos)))

    def __delitem__(self, pos):
        """Delete a pair by its position."""
        if not isinstance(pos, int):
            raise TypeError('expecting int, got {0.__name__!r}'.format(type(pos)))
        size = len(self)
        if pos < 0:
            pos += size
        if not 0 <= pos < size:
            raise IndexError('list index out of range')
        self._find_pos(pos)
        node = self._path[0][2]
        self._remove(node)

    def __setitem__(self, pos, value):
        """Set a value by its position."""
        if not isinstance(pos, int):
            raise TypeError('expecting int, got {0.__name__!r}'.format(type(pos)))
        size = len(self)
        if pos < 0:
            pos += size
        if not 0 <= pos < size:
            raise IndexError('list index out of range')
        self._find_pos(pos)
        node = self._path[0][2]
        node[1] = value

    # our custom in function with a filter
    # not pretty, but hey... if it works
    def custom_in_with_filter(self, key, skiplist_filter: typing.Callable):
        """Return whether *key* is contained in the list."""
        self._find_lt(key, skiplist_filter)
        node = self._last_comparable_node_higher
        return node is not self._tail and not key < node[0]

# %%
from dataclasses import dataclass

@dataclass
class SkiplistNode:
    """Declare SkipListNode class for export in dumpNodes()"""
    level: int
    key: str
    value: list
    name: str = None

def getSkiplistNodeData(node):
    level = max(1, len(node) - 3)
    key = node[0]
    value = [node[1]][0]
    return(level, key, value)

def dumpNodes(sl):
    SkiplistNodes = []
    node = sl._head
    nodeValues = getSkiplistNodeData(node)
    SkiplistNodes.append(SkiplistNode(level=nodeValues[0], key=nodeValues[1], value=nodeValues[2], name="head"))
    node = node[2]
    while node is not sl._tail:
        nodeValues = getSkiplistNodeData(node)
        SkiplistNodes.append(SkiplistNode(level=nodeValues[0], key=nodeValues[1], value=nodeValues[2]))
        node = node[2]
    nodeValues = getSkiplistNodeData(node)
    SkiplistNodes.append(SkiplistNode(level=nodeValues[0], key=nodeValues[1], value=nodeValues[2], name="tail"))
    return SkiplistNodes

def floor(sl: SkipList, key: str) -> str:
    """Return highest key value that is less than the new key that we seek to place

    Assumption: keys are unique
    Note: lt, not le (unlike Java)"""
    sl._find_lte(key) # change state (eek!)
    return sl._path[0][0] if sl._path[0] else None

def ceiling(sl: SkipList, key: str) -> str:
    """Return lowest value that is greater than the new key that we seek to place

    Assumption: keys are unique
    Note: gt, not ge (unlike Java)"""

    sl._find_lte(key) # change state (eek!)
    return sl._last_comparable_node_higher[0] if sl._last_comparable_node_higher else None

import typing
def floor_and_ceiling(sl: SkipList, key: str, skiplist_filter: typing.Callable) -> tuple:
    """Return tuple of (floor, ceiling), both of which are skiplist nodes

    Neither can be None; start and end nodes always satisfy filter
    Assumption: keys are unique
    Note: lt and gt, not le and ge (unlike Java)"""
    sl._find_lte(key, skiplist_filter) # change state (eek!)
    _floor = sl._path[0][0]
    _ceiling = sl._last_comparable_node_higher[0]
    return (_floor, _ceiling)

# %%
from functools import total_ordering

# Find all witness that are present on both items (ignore those on only one item)
#     If none, raise an error
#     If some, compare in arbitrary but consistent order
#         If first pair differs, return result
#         If first pair matches, check next pair

class ComparisonError(Exception):
    def __init__(self, message):
        self.message = message
    def __str__(self):
        return self.message

@total_ordering
class VG_node():
    """Variant graph node, used as key in skiplist

    We don't care about the value in the skiplist; the node contains all information"""
    def __init__(self, block_id=None, token_offset=None, **kwargs):
        self.__dict__.update(kwargs)
        self._sigla = {key for key in kwargs.keys()}
        self.block_id = block_id
        self.token_offset = token_offset
    def __repr__(self):
        return "|".join([":".join([str(key), str(getattr(self, key))]) for key in self.sigla()])
    def __setitem__(self, key, value):
        self._sigla.add(key)
        self.__dict__[key] = value
    def __getitem__(self, key):
        return self.__dict__[key]
    def __contains__(self, key):
        return key in self.__dict__
    def sigla(self):
        return self._sigla
    def find_shared_sigla(self, other):
        """Return shared sigla for use in comparison, raise error if none"""
        shared_sigla = sorted(set(self.sigla()).intersection(set(other.sigla())))
        if not shared_sigla:
            raise ComparisonError("No shared sigla; cannot be compared")
        return shared_sigla
    def __eq__(self, other):
        shared_sigla = self.find_shared_sigla(other)
        return [getattr(self, siglum) for siglum in shared_sigla] == [getattr(other, siglum) for siglum in shared_sigla]
    def __lt__(self, other):
        shared_sigla = self.find_shared_sigla(other)
#         print("We are comparing the following sigla: "+str(shared_sigla))
#         print(str(self) + " : " + str(other))
        return [getattr(self, siglum) for siglum in shared_sigla] < [getattr(other, siglum) for siglum in shared_sigla]

# %%
# we can use token-string frequency (overall) to align rare tokens first within each block
from collections import Counter
all_token_frequencies = Counter(token_array)
# exclude singletons (not in blocks)
token_frequencies = {k:v for k, v in all_token_frequencies.items() if v > 1}
# bitarray keeps track of which tokens we've already placed in skiplist
from bitarray import bitarray
placed_tokens = bitarray(len(token_array))
placed_tokens.setall(0)
# print(placed_tokens) # take a look

# %%
# pp.pprint(token_frequencies) # take a look

# %% [markdown]
# # Skiplist setup code above, now create vg (variant graph) skiplist below

# %% [markdown]
# # Import code to generate SVG of skiplist from render_skiplist_as_svg.ipynb

# %%
vg = SkipList()
tail_value = len(token_array) + 1
vg.insert(VG_node(w0=-1, w1=-1, w2=-1, w3=-1), ['[START]'])
vg.insert(VG_node(w0=tail_value, w1=tail_value, w2=tail_value, w3=tail_value), ['[END]'])

for index, prioritized_block in enumerate(prioritized_blocks):
    # add each token from the block individually
    # first block: Block(token_count=2, start_position=4, end_position=6, all_start_positions=[2, 9, 18], witnesses={0, 1, 2}, witness_count=3, frequency=3)
    if index: # limit number of blocks for testing; open the limit for production (currently breaks at 20)
        print(f'Processing block #{index}')

        #####
        # Change order:
        # Old: first each witness, then each offset by inverse token frequency
        #   Wrong because it places high-frequency token in first witness before low-frequency token in other
        # New: first each offset by inverse frequency, then same offset for each witness
        #####

        all_offsets = range(prioritized_block.token_count)

        #####
        # from the inside out:
        # 1. take an arbitrary start position from the list of all start positions
        # 2. add each offset to it in turn and use that to retrieve a string from token_array
        # 3. use that string to retrieve a frequency from token_frequencies
        # 4. sort the offsets according to the frequency of the associated tokens (from low to high)
        # 5. we will then be able to process the offsets in order of inverse frequency
        #####
        sorted_offsets = sorted(all_offsets, key=lambda x: token_frequencies[token_array[prioritized_block.all_start_positions[0] + x]])
#         pp.pprint(
#             [(token_array[x + prioritized_block.all_start_positions[0]], token_frequencies[token_array[x + prioritized_block.all_start_positions[0]]]) for x in sorted_offsets])

        for sorted_offset in sorted_offsets:
            for start_position in prioritized_block.all_start_positions:
                witness_token_pos = sorted_offset + start_position

                if placed_tokens[witness_token_pos]:
                    continue # already placed, so look at the next token

                placed_tokens[witness_token_pos] = 1 # we're going to place it below

                #####
                # We go from lower to higher frequency, but we do an entire witness at a time, which is wrong.
                # We need, instead, to go from lower to higher frequency but place the token for all witnesses
                #   before moving on to the next token.
                #####

                current_witness = 'w' + str(token_membership_array[witness_token_pos])

                # function to filter skiplist (to be passed into skiplist API)
                # keep nodes that have:
                #   1) the siglum of interest (= current_witness variable)
                #.  2) at least two sigla
                siglum_filter = lambda x: current_witness in x.sigla() and len(x.sigla()) > 1

                key_to_check = VG_node(index, sorted_offset, **{current_witness: witness_token_pos})
                # if not tuple_to_token_map contains (index, token_offset_in_block) put it in there
                # If it is there, check whether it is the same token/string.
                string_to_look_for = token_array[witness_token_pos]

                #####
                # Old code resumes (safely) here
                #####

                # print('we are checking ' + str(key_to_check))
                # TODO: check this in the bitarray
                # TODO: we may not need our custom "in" now that we filter for siglum here
                if not vg.custom_in_with_filter(key_to_check, lambda x: current_witness in x.sigla()):
                    # print('we need to add  ', str(key_to_check))
                    # floor_node = floor(vg, key_to_check)
                    # print('floor =         ', floor_node)
                    # ceiling_node = ceiling(vg, key_to_check)
                    # print('ceiling =       ', ceiling_node)
                    floor_node, ceiling_node = floor_and_ceiling(vg, key_to_check, siglum_filter)

#                     if index == 19:
#                         print("We are trying to place "+str(key_to_check))
#                         print('floor = ', floor_node)
#                         print('ceiling = ', ceiling_node)
#                         print('What does the skiplist look like at this time?')
#                         for node_position, node in enumerate(vg.keys()):
#                             print('Node position: ' + str(node_position) + ': ' + str(node))

                    # create a list of the items between the floor and ceiling
                    # floor is inclusive, ceiling is exclusive in the skiplist items method. 
                    floor_filter = lambda x: floor_node.sigla() == x.sigla()
                    ceiling_filter = lambda x: ceiling_node.sigla() == x.sigla()
                    gen = vg.items(floor_node, ceiling_node, floor_filter, ceiling_filter)
                    # we have to skip the floor node
                    zzz = next(gen)
                    current_slice = list(gen)
#                     if index == 19:
#                         print(f"{zzz=}")
#                         print(f"{len(current_slice)=}")
                    # print(current_slice)
                    if not len(current_slice): # floor and ceiling are adjacent, so insert between them
                        # insertion position is automatic for a skiplist (if the comparator is doing its job)
                        vg.insert(key_to_check, [witness_token_pos], lambda x: current_witness in x.sigla())
                    else: # do stuff
                        # print()
                        # #####
                        # Are any of the slice nodes candidates for placing new token?
                        # Blocks contain information about all occurrences of pattern.
                        # If token is part of the same block, it can be added to it?
                        #
                        # We already did string matching when we constructed blocks. Now
                        # find intersection of:
                        #   1) nodes between floor and ceiling and
                        #   2) instances of block
                        # If there is an intersection, that's the node with which to align.
                        # To do that:
                        #   1) Remove the existing node
                        #   2) Modify its key (and value?) and insert it
                        # We think it will go back into the same place, but if not, the
                        # skiplist should place it correctly (topologically) anyway.
                        # NB: We do not modify the key or value in place!
                        #
                        # Possibilities:
                        #   1) none
                        #      Insert new node
                        #   2) exactly one
                        #      Add to it
                        #   3) more than one (if there is repetition)
                        #      Defer consideration until we encounter one
                        #
                        # print(f"{slice_length=}") # diagnostic
                        #
                        # Is it situation 1, 2, or 3?
                        #
                        # token_to_block_dict is a multi-valued dictionary:
                        #   keys are token offsets
                        #   values are lists of block offsets in  prioritized_blocks list, which serve as block ids
                        for current_node in current_slice: # look at all vg nodes between floor and ceiling; tuple of vg_node, [offsets]
                            # print("We are visiting "+str(current_node)+" as a potential candidate for alignment")
                            # index is for block we're trying to place; is in graph between floor and ceiling?
                            blocks_for_vg_node = [] # blocks associated with current variant graph node
                            for current_token_offset in current_node[1]: # for each node, look at each of its values
                                blocks_for_current_token = token_to_block_dict[current_token_offset] # non-empty list of integers
                                blocks_for_vg_node.extend(blocks_for_current_token) # list may include duplicates; do we care?
                            # print(f"{blocks_for_vg_node=}")
                            #     if token_offset_in_block == current_node[0].token_offset and index in blocks_for_vg_node: # does the current block, inside the slice, contain the node we care about?
                            if current_witness not in current_node[0].sigla() and token_array[current_node[1][0]] == token_array[witness_token_pos]:
#                                 if index == 19:
#                                     print(f'Before remove: {vg=}')
#                                     print(f'Before remove: {current_node[0]=}')
#                                     print(f'{current_witness=}')
#                                     print('new_key_siglum will equal: w' + str(token_membership_array[witness_token_pos]))
                                # vg.remove(current_node[0], lambda x: x == current_node[0]) # found one; remove matching node by key
                                vg.remove(current_node[0], lambda x: set(x.sigla()).intersection(set(current_node[0].sigla()))) # found one; remove matching node by key
#                                 if index == 19:
#                                     print(f'After remove: {current_node[0]=}')
#                                     print(f'After remove: {vg=}')
#                                 new_key_siglum = 'w' + str(token_membership_array[witness_token_pos]) # witness siglum for new token instance
#                                 if new_key_siglum in new_key:
#                                     raise Exception("The key is already on this node")
                                current_node[0][current_witness] = witness_token_pos # add new token to key
                                current_node[1].append(witness_token_pos) # add new token to value, too
                                # print(new_key, new_value)

                                # Debug: CHECK whether the token content is the same when adding an offset to an existing node.
#                                 string_already_on_the_node = token_array[current_node[1][0]]
#                                 string_to_be_placed = token_array[witness_token_pos]
#                                 if new_key_siglum == "w0" and string_already_on_the_node != string_to_be_placed:
#                                     raise Exception(string_already_on_the_node+" != "+string_to_be_placed+" Nodes to check: "+str(current_slice)+" floor: "+str(floor_node)+" : "+str(ceiling_node))


                                vg.insert(current_node[0], current_node[1], lambda x: set(x.sigla()).intersection(set(current_node[0].sigla()))) # update key and value, insert
                                break
                        else:
                            # didn't find one, insert new; look only at nodes with current siglum
                            vg.insert(key_to_check, [witness_token_pos], lambda x: current_witness in x.sigla())

# place tokens that are not parts of blocks
unplaced_tokens = [offset for offset in range(len(token_array))
                   if offset not in token_to_block_dict
                   and isinstance(token_membership_array[offset], int)]
for unplaced_token in unplaced_tokens:
    current_witness = 'w' + str(token_membership_array[unplaced_token])
    new_node = VG_node(**{current_witness: unplaced_token})
    vg.insert(new_node, [unplaced_token], lambda x: current_witness in x.sigla())

# dumpNodes(vg) # take a look
# pp.pprint(prioritized_blocks) # take a look at this, too
# Out:
# Processing block #1
# Processing block #2
# Processing block #3
# Processing block #4
# Processing block #5
# Processing block #6
# Processing block #7
# Processing block #8
# Processing block #9
# Processing block #10
# Processing block #11
# Processing block #12
# Processing block #13
# Processing block #14
# Processing block #15
# Processing block #16
# Processing block #17
# Processing block #18
# Processing block #19
# Processing block #20
# Processing block #21
# Processing block #22
# Processing block #23
# Processing block #24
# Processing block #25
# Processing block #26
# Processing block #27
# Processing block #28
# Processing block #29
# Processing block #30
# Processing block #31
# Processing block #32
# Processing block #33
# Processing block #34
# Processing block #35
# Processing block #36
# Processing block #37
# Processing block #38
# Processing block #39
# Processing block #40
# Processing block #41
# Processing block #42
# Processing block #43
# Processing block #44
# Processing block #45
# Processing block #46
# Processing block #47
# Processing block #48
# Processing block #49
# Processing block #50
# Processing block #51
# Processing block #52
# Processing block #53
# Processing block #54
# Processing block #55
# Processing block #56
# Processing block #57
# Processing block #58
# Processing block #59
# Processing block #60
# Processing block #61
# Processing block #62
# Processing block #63
# Processing block #64
# Processing block #65
# Processing block #66
# Processing block #67
# Processing block #68
# Processing block #69
# Processing block #70
# Processing block #71
# Processing block #72
# Processing block #73
# Processing block #74
# Processing block #75
# Processing block #76
# Processing block #77
# Processing block #78
# Processing block #79
# Processing block #80
# Processing block #81
# Processing block #82
# Processing block #83
# Processing block #84
# Processing block #85
# Processing block #86
# Processing block #87
# Processing block #88
# Processing block #89
# Processing block #90
# Processing block #91
# Processing block #92
# Processing block #93
# Processing block #94
# Processing block #95
# Processing block #96
# Processing block #97
# Processing block #98
# Processing block #99
# Processing block #100
# Processing block #101
# Processing block #102
# Processing block #103
# Processing block #104
# Processing block #105
# Processing block #106
# Processing block #107
# Processing block #108
# Processing block #109
# Processing block #110
# Processing block #111
# Processing block #112
# Processing block #113
# Processing block #114
# Processing block #115
# Processing block #116
# Processing block #117
# Processing block #118
# Processing block #119
# Processing block #120
# Processing block #121
# Processing block #122
# Processing block #123
# Processing block #124
# Processing block #125
# Processing block #126
# Processing block #127
# Processing block #128
# Processing block #129
# Processing block #130
# Processing block #131
# Processing block #132
# Processing block #133
# Processing block #134
# Processing block #135
# Processing block #136
# Processing block #137
# Processing block #138
# Processing block #139
# Processing block #140
# Processing block #141
# Processing block #142
# Processing block #143
# Processing block #144
# Processing block #145
# Processing block #146
# Processing block #147
# Processing block #148
# Processing block #149
# Processing block #150
# Processing block #151
# Processing block #152
# Processing block #153
# Processing block #154
# Processing block #155
# Processing block #156
# Processing block #157
# Processing block #158
# Processing block #159
# Processing block #160
# Processing block #161
# Processing block #162
# Processing block #163
# Processing block #164
# Processing block #165
# Processing block #166
# Processing block #167
# Processing block #168
# Processing block #169
# Processing block #170
# Processing block #171
# Processing block #172
# Processing block #173
# Processing block #174
# Processing block #175
# Processing block #176
# Processing block #177
# Processing block #178
# Processing block #179
# Processing block #180
# Processing block #181
# Processing block #182
# Processing block #183
# Processing block #184
# Processing block #185
# Processing block #186
# Processing block #187
# Processing block #188
# Processing block #189
# Processing block #190
# Processing block #191
# Processing block #192
# Processing block #193
# Processing block #194
# Processing block #195
# Processing block #196
# Processing block #197
# Processing block #198
# Processing block #199
# Processing block #200
# Processing block #201
# Processing block #202
# Processing block #203
# Processing block #204
# Processing block #205
# Processing block #206
# Processing block #207
# Processing block #208
# Processing block #209
# Processing block #210
# Processing block #211
# Processing block #212
# Processing block #213
# Processing block #214
# Processing block #215
# Processing block #216
# Processing block #217
# Processing block #218
# Processing block #219
# Processing block #220
# Processing block #221
# Processing block #222
# Processing block #223
# Processing block #224
# Processing block #225
# Processing block #226
# Processing block #227
# Processing block #228
# Processing block #229
# Processing block #230
# Processing block #231
# Processing block #232
# Processing block #233
# Processing block #234
# Processing block #235
# Processing block #236
# Processing block #237
# Processing block #238
# Processing block #239
# Processing block #240
# Processing block #241
# Processing block #242
# Processing block #243
# Processing block #244
# Processing block #245
# Processing block #246
# Processing block #247
# Processing block #248
# Processing block #249
# Processing block #250
# Processing block #251
# Processing block #252
# Processing block #253
# Processing block #254
# Processing block #255
# Processing block #256
# Processing block #257
# Processing block #258
# Processing block #259
# Processing block #260
# Processing block #261
# Processing block #262
# Processing block #263
# Processing block #264
# Processing block #265
# Processing block #266
# Processing block #267
# Processing block #268
# Processing block #269
# Processing block #270
# Processing block #271
# Processing block #272
# Processing block #273
# Processing block #274
# Processing block #275
# Processing block #276
# Processing block #277
# Processing block #278
# Processing block #279
# Processing block #280
# Processing block #281
# Processing block #282
# Processing block #283
# Processing block #284
# Processing block #285
# Processing block #286
# Processing block #287
# Processing block #288
# Processing block #289
# Processing block #290
# Processing block #291
# Processing block #292
# Processing block #293
# Processing block #294
# Processing block #295
# Processing block #296
# Processing block #297
# Processing block #298
# Processing block #299
# Processing block #300
# Processing block #301
# Processing block #302
# Processing block #303
# Processing block #304
# Processing block #305
# Processing block #306
# Processing block #307
# Processing block #308
# Processing block #309
# Processing block #310
# Processing block #311
# Processing block #312
# Processing block #313
# Processing block #314
# Processing block #315
# Processing block #316
# Processing block #317
# Processing block #318
# Processing block #319
# Processing block #320
# Processing block #321
# Processing block #322
# Processing block #323
# Processing block #324
# Processing block #325
# Processing block #326
# Processing block #327
# Processing block #328
# Processing block #329
# Processing block #330
# Processing block #331
# Processing block #332
# Processing block #333
# Processing block #334
# Processing block #335
# Processing block #336
# Processing block #337
# Processing block #338
# Processing block #339
# Processing block #340
# Processing block #341
# Processing block #342
# Processing block #343
# Processing block #344
# Processing block #345
# Processing block #346
# Processing block #347
# Processing block #348
# Processing block #349
# Processing block #350
# Processing block #351
# Processing block #352
# Processing block #353
# Processing block #354
# Processing block #355
# Processing block #356
# Processing block #357
# Processing block #358
# Processing block #359
# Processing block #360
# Processing block #361
# Processing block #362
# Processing block #363
# Processing block #364
# Processing block #365
# Processing block #366
# Processing block #367
# Processing block #368
# Processing block #369
# Processing block #370
# Processing block #371
# Processing block #372
# Processing block #373
# Processing block #374
# Processing block #375
# Processing block #376
# Processing block #377
# Processing block #378
# Processing block #379
# Processing block #380
# Processing block #381
# Processing block #382
# Processing block #383
# Processing block #384
# Processing block #385
# Processing block #386
# Processing block #387
# Processing block #388
# Processing block #389
# Processing block #390
# Processing block #391
# Processing block #392
# Processing block #393
# Processing block #394
# Processing block #395
# Processing block #396
# Processing block #397
# Processing block #398
# Processing block #399
# Processing block #400
# Processing block #401
# Processing block #402
# Processing block #403
# Processing block #404
# Processing block #405
# Processing block #406
# Processing block #407
# Processing block #408
# Processing block #409
# Processing block #410
# Processing block #411
# Processing block #412
# Processing block #413
# Processing block #414
# Processing block #415
# Processing block #416
# Processing block #417
# Processing block #418
# Processing block #419
# Processing block #420
# Processing block #421
# Processing block #422
# Processing block #423
# Processing block #424
# Processing block #425
# Processing block #426
# Processing block #427
# Processing block #428
# Processing block #429
# Processing block #430
# Processing block #431
# Processing block #432
# Processing block #433
# Processing block #434
# Processing block #435
# Processing block #436
# Processing block #437
# Processing block #438
# Processing block #439
# Processing block #440
# Processing block #441
# Processing block #442
# Processing block #443
# Processing block #444
# Processing block #445
# Processing block #446
# Processing block #447
# Processing block #448
# Processing block #449
# Processing block #450
# Processing block #451
# Processing block #452
# Processing block #453
# Processing block #454
# Processing block #455
# Processing block #456
# Processing block #457
# Processing block #458
# Processing block #459
# Processing block #460
# Processing block #461
# Processing block #462
# Processing block #463
# Processing block #464
# Processing block #465
# Processing block #466
# Processing block #467
# Processing block #468
# Processing block #469
# Processing block #470
# Processing block #471
# Processing block #472
# Processing block #473
# Processing block #474
# Processing block #475
# Processing block #476
# Processing block #477
# Processing block #478
# Processing block #479
# Processing block #480
# Processing block #481
# Processing block #482
# Processing block #483
# Processing block #484
# Processing block #485
# Processing block #486
# Processing block #487
# Processing block #488
# Processing block #489
# Processing block #490
# Processing block #491
# Processing block #492
# Processing block #493
# Processing block #494
# Processing block #495
# Processing block #496
# Processing block #497
# Processing block #498
# Processing block #499
# Processing block #500
# Processing block #501
# Processing block #502
# Processing block #503
# Processing block #504
# Processing block #505
# Processing block #506
# Processing block #507
# Processing block #508
# Processing block #509
# Processing block #510
# Processing block #511
# Processing block #512
# Processing block #513
# Processing block #514
# Processing block #515
# Processing block #516
# Processing block #517
# Processing block #518
# Processing block #519
# Processing block #520
# Processing block #521
# Processing block #522
# Processing block #523
# Processing block #524
# Processing block #525
# Processing block #526
# Processing block #527
# Processing block #528
# Processing block #529
# Processing block #530
# Processing block #531
# Processing block #532
# Processing block #533
# Processing block #534
# Processing block #535
# Processing block #536
# Processing block #537
# Processing block #538
# Processing block #539
# Processing block #540
# Processing block #541
# Processing block #542
# Processing block #543
# Processing block #544
# Processing block #545
# Processing block #546
# Processing block #547
# Processing block #548
# Processing block #549
# Processing block #550
# Processing block #551
# Processing block #552
# Processing block #553
# Processing block #554
# Processing block #555
# Processing block #556
# Processing block #557
# Processing block #558
# Processing block #559
# Processing block #560
# Processing block #561
# Processing block #562
# Processing block #563
# Processing block #564
# Processing block #565
# Processing block #566
# Processing block #567
# Processing block #568
# Processing block #569
# Processing block #570
# Processing block #571
# Processing block #572
# Processing block #573
# Processing block #574

# %%
# %run render_skiplist_as_svg.ipynb

# %% [markdown]
# # Import code to generate SVG of variant graph from render_variant_graph_as_svg.ipynb
#
# Rendering instruction in imported module doesn’t work; we need it issue it here

# %%
# get ready to visualize the decision tree in SVG
import graphviz
from IPython.display import SVG
from collections import defaultdict

# TODO: use tm instead of to_variant_graph_nodes because reasons
# TODO: add token offsets with witness identifiers to label

# node id values must be strings for graphviz
a = graphviz.Digraph(format="svg")
a.attr(rankdir = "LR")
# #####
# new code starts here
# #####
for index, vg_node in enumerate(dumpNodes(vg)[1:-1]): # list of SkiplistNode objects, omit head and tail
# create nodes
    node_id = str(index)
    block_id = vg_node.key.block_id
    token_string = token_array[vg_node.value[0]] if isinstance(vg_node.value[0], int) else vg_node.value[0]
    all_token_offsets = ",".join([str(x) for x in vg_node.value])
    a.node(node_id, label=(node_id + ':' + token_string + '(' + str(block_id) + ')(' + all_token_offsets + ')'))
# create edges witness by witness
# print([x.key.sigla() for x in dumpNodes(vg)[1:-1]]) # keys for all skiplist nodes are variant-graph nodes, which have a sigla() method
# for w in range(len(witnesses)): # w is offset of witness in list of witnesses
#     siglum = 'w' + str(w) # siglum as recorded in SkiplistNode keys
#     # witness_nodes = filter(lambda x: siglum in x.key.sigla(), dumpNodes(vg)[1:-1]) # this loses the original position, which is the node id in the variant graph
#     # print(list(witness_nodes)) take a look
#     witness_nodes = []
#     for index, vg_node in enumerate(dumpNodes(vg)[1:-1]):
#         if siglum in vg_node.key.sigla():
#             witness_nodes.append(index)
#     for source, target in zip(witness_nodes, witness_nodes[1:]):
#         a.edge(str(source), str(target), label=str(siglum))

# create dictionary of all edges; key is (source, target) node id, value is list of sigla
all_edges = defaultdict(list)
for w in range(len(witnesses)): # w is offset of witness in list of witnesses
    siglum = 'w' + str(w) # siglum as recorded in SkiplistNode keys
    witness_nodes = []
    for index, vg_node in enumerate(dumpNodes(vg)[1:-1]):
        if siglum in vg_node.key.sigla():
            witness_nodes.append(index)
    for source, target in zip(witness_nodes, witness_nodes[1:]):
        all_edges[(source, target)].append(siglum)

# add edges to graph
for edge_endpoints, sigla in all_edges.items():
    a.edge(str(edge_endpoints[0]), str(edge_endpoints[1]), label=",".join(sigla))

SVG(a.view())

# %%
# for index,node in enumerate(dumpNodes(vg)):
#     pp.pprint((index,node))

# %%
# list(enumerate(token_array))

# %%
pp.pprint(list(enumerate(prioritized_blocks)))
# Out:
# [ ( 0,
#     Block(token_count=176, start_position=37, end_position=39, all_start_positions=[234, 467, 703], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 1,
#     Block(token_count=175, start_position=895, end_position=897, all_start_positions=[235, 468, 704], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 2,
#     Block(token_count=174, start_position=401, end_position=403, all_start_positions=[236, 469, 705], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 3,
#     Block(token_count=173, start_position=791, end_position=793, all_start_positions=[237, 470, 706], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 4,
#     Block(token_count=172, start_position=715, end_position=717, all_start_positions=[238, 471, 707], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 5,
#     Block(token_count=171, start_position=369, end_position=371, all_start_positions=[239, 472, 708], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 6,
#     Block(token_count=170, start_position=491, end_position=493, all_start_positions=[240, 473, 709], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 7,
#     Block(token_count=169, start_position=739, end_position=741, all_start_positions=[241, 474, 710], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 8,
#     Block(token_count=168, start_position=627, end_position=629, all_start_positions=[242, 475, 711], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 9,
#     Block(token_count=167, start_position=871, end_position=873, all_start_positions=[243, 476, 712], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 10,
#     Block(token_count=166, start_position=539, end_position=541, all_start_positions=[244, 477, 713], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 11,
#     Block(token_count=165, start_position=675, end_position=677, all_start_positions=[245, 478, 714], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 12,
#     Block(token_count=164, start_position=475, end_position=477, all_start_positions=[246, 479, 715], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 13,
#     Block(token_count=163, start_position=563, end_position=565, all_start_positions=[247, 480, 716], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 14,
#     Block(token_count=162, start_position=503, end_position=505, all_start_positions=[248, 481, 717], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 15,
#     Block(token_count=161, start_position=217, end_position=219, all_start_positions=[249, 482, 718], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 16,
#     Block(token_count=160, start_position=583, end_position=585, all_start_positions=[250, 483, 719], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 17,
#     Block(token_count=159, start_position=73, end_position=75, all_start_positions=[251, 484, 720], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 18,
#     Block(token_count=158, start_position=101, end_position=103, all_start_positions=[252, 485, 721], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 19,
#     Block(token_count=157, start_position=527, end_position=529, all_start_positions=[253, 486, 722], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 20,
#     Block(token_count=156, start_position=483, end_position=485, all_start_positions=[254, 487, 723], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 21,
#     Block(token_count=155, start_position=707, end_position=709, all_start_positions=[255, 488, 724], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 22,
#     Block(token_count=154, start_position=293, end_position=295, all_start_positions=[256, 489, 725], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 23,
#     Block(token_count=153, start_position=591, end_position=593, all_start_positions=[257, 490, 726], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 24,
#     Block(token_count=152, start_position=919, end_position=921, all_start_positions=[258, 491, 727], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 25,
#     Block(token_count=151, start_position=671, end_position=673, all_start_positions=[259, 492, 728], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 26,
#     Block(token_count=150, start_position=835, end_position=837, all_start_positions=[260, 493, 729], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 27,
#     Block(token_count=149, start_position=385, end_position=387, all_start_positions=[261, 494, 730], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 28,
#     Block(token_count=148, start_position=691, end_position=693, all_start_positions=[262, 495, 731], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 29,
#     Block(token_count=147, start_position=751, end_position=753, all_start_positions=[263, 496, 732], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 30,
#     Block(token_count=146, start_position=317, end_position=319, all_start_positions=[264, 497, 733], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 31,
#     Block(token_count=145, start_position=233, end_position=235, all_start_positions=[265, 498, 734], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 32,
#     Block(token_count=144, start_position=417, end_position=419, all_start_positions=[266, 499, 735], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 33,
#     Block(token_count=143, start_position=305, end_position=307, all_start_positions=[267, 500, 736], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 34,
#     Block(token_count=142, start_position=277, end_position=279, all_start_positions=[268, 501, 737], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 35,
#     Block(token_count=141, start_position=555, end_position=557, all_start_positions=[269, 502, 738], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 36,
#     Block(token_count=140, start_position=683, end_position=685, all_start_positions=[270, 503, 739], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 37,
#     Block(token_count=139, start_position=249, end_position=251, all_start_positions=[271, 504, 740], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 38,
#     Block(token_count=138, start_position=711, end_position=713, all_start_positions=[272, 505, 741], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 39,
#     Block(token_count=137, start_position=365, end_position=367, all_start_positions=[273, 506, 742], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 40,
#     Block(token_count=136, start_position=455, end_position=457, all_start_positions=[274, 507, 743], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 41,
#     Block(token_count=135, start_position=109, end_position=111, all_start_positions=[275, 508, 744], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 42,
#     Block(token_count=134, start_position=531, end_position=533, all_start_positions=[276, 509, 745], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 43,
#     Block(token_count=133, start_position=655, end_position=657, all_start_positions=[277, 510, 746], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 44,
#     Block(token_count=132, start_position=543, end_position=545, all_start_positions=[278, 511, 747], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 45,
#     Block(token_count=131, start_position=867, end_position=869, all_start_positions=[279, 512, 748], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 46,
#     Block(token_count=55, start_position=907, end_position=910, all_start_positions=[178, 411, 644, 880], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 47,
#     Block(token_count=130, start_position=357, end_position=359, all_start_positions=[280, 513, 749], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 48,
#     Block(token_count=129, start_position=45, end_position=47, all_start_positions=[281, 514, 750], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 49,
#     Block(token_count=128, start_position=659, end_position=661, all_start_positions=[282, 515, 751], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 50,
#     Block(token_count=54, start_position=683, end_position=686, all_start_positions=[37, 270, 503, 739], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 51,
#     Block(token_count=54, start_position=727, end_position=730, all_start_positions=[179, 412, 645, 881], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 52,
#     Block(token_count=127, start_position=471, end_position=473, all_start_positions=[283, 516, 752], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 53,
#     Block(token_count=126, start_position=434, end_position=436, all_start_positions=[284, 517, 753], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 54,
#     Block(token_count=53, start_position=249, end_position=252, all_start_positions=[38, 271, 504, 740], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 55,
#     Block(token_count=53, start_position=551, end_position=554, all_start_positions=[180, 413, 646, 882], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 56,
#     Block(token_count=125, start_position=41, end_position=43, all_start_positions=[285, 518, 754], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 57,
#     Block(token_count=124, start_position=899, end_position=901, all_start_positions=[286, 519, 755], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 58,
#     Block(token_count=52, start_position=333, end_position=336, all_start_positions=[181, 414, 647, 883], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 59,
#     Block(token_count=52, start_position=711, end_position=714, all_start_positions=[39, 272, 505, 741], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 60,
#     Block(token_count=123, start_position=623, end_position=625, all_start_positions=[287, 520, 756], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 61,
#     Block(token_count=122, start_position=519, end_position=521, all_start_positions=[288, 521, 757], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 62,
#     Block(token_count=121, start_position=743, end_position=745, all_start_positions=[289, 522, 758], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 63,
#     Block(token_count=51, start_position=365, end_position=368, all_start_positions=[40, 273, 506, 742], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 64,
#     Block(token_count=51, start_position=523, end_position=526, all_start_positions=[182, 415, 648, 884], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 65,
#     Block(token_count=120, start_position=883, end_position=885, all_start_positions=[290, 523, 759], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 66,
#     Block(token_count=119, start_position=245, end_position=247, all_start_positions=[291, 524, 760], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 67,
#     Block(token_count=50, start_position=61, end_position=64, all_start_positions=[127, 360, 593, 829], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 68,
#     Block(token_count=50, start_position=157, end_position=160, all_start_positions=[183, 416, 649, 885], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 69,
#     Block(token_count=50, start_position=455, end_position=458, all_start_positions=[41, 274, 507, 743], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 70,
#     Block(token_count=118, start_position=487, end_position=489, all_start_positions=[292, 525, 761], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 71,
#     Block(token_count=117, start_position=735, end_position=737, all_start_positions=[293, 526, 762], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 72,
#     Block(token_count=49, start_position=12, end_position=15, all_start_positions=[128, 361, 594, 830], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 73,
#     Block(token_count=49, start_position=109, end_position=112, all_start_positions=[42, 275, 508, 744], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 74,
#     Block(token_count=49, start_position=803, end_position=806, all_start_positions=[184, 417, 650, 886], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 75,
#     Block(token_count=116, start_position=579, end_position=581, all_start_positions=[294, 527, 763], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 76,
#     Block(token_count=115, start_position=69, end_position=71, all_start_positions=[295, 528, 764], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 77,
#     Block(token_count=114, start_position=97, end_position=99, all_start_positions=[296, 529, 765], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 78,
#     Block(token_count=48, start_position=531, end_position=534, all_start_positions=[43, 276, 509, 745], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 79,
#     Block(token_count=48, start_position=759, end_position=762, all_start_positions=[129, 362, 595, 831], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 80,
#     Block(token_count=48, start_position=879, end_position=882, all_start_positions=[185, 418, 651, 887], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 81,
#     Block(token_count=113, start_position=911, end_position=913, all_start_positions=[297, 530, 766], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 82,
#     Block(token_count=112, start_position=337, end_position=339, all_start_positions=[298, 531, 767], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 83,
#     Block(token_count=47, start_position=389, end_position=392, all_start_positions=[186, 419, 652, 888], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 84,
#     Block(token_count=47, start_position=647, end_position=650, all_start_positions=[130, 363, 596, 832], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 85,
#     Block(token_count=47, start_position=655, end_position=658, all_start_positions=[44, 277, 510, 746], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 86,
#     Block(token_count=111, start_position=145, end_position=147, all_start_positions=[299, 532, 768], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 87,
#     Block(token_count=110, start_position=225, end_position=227, all_start_positions=[300, 533, 769], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 88,
#     Block(token_count=46, start_position=313, end_position=316, all_start_positions=[187, 420, 653, 889], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 89,
#     Block(token_count=46, start_position=543, end_position=546, all_start_positions=[45, 278, 511, 747], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 90,
#     Block(token_count=46, start_position=599, end_position=602, all_start_positions=[131, 364, 597, 833], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 91,
#     Block(token_count=109, start_position=89, end_position=91, all_start_positions=[301, 534, 770], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 92,
#     Block(token_count=108, start_position=915, end_position=917, all_start_positions=[302, 535, 771], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 93,
#     Block(token_count=107, start_position=345, end_position=347, all_start_positions=[303, 536, 772], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 94,
#     Block(token_count=45, start_position=213, end_position=216, all_start_positions=[188, 421, 654, 890], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 95,
#     Block(token_count=45, start_position=361, end_position=364, all_start_positions=[132, 365, 598, 834], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 96,
#     Block(token_count=45, start_position=867, end_position=870, all_start_positions=[46, 279, 512, 748], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 97,
#     Block(token_count=106, start_position=61, end_position=63, all_start_positions=[127, 360, 593], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 98,
#     Block(token_count=106, start_position=859, end_position=861, all_start_positions=[304, 537, 773], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 99,
#     Block(token_count=105, start_position=12, end_position=14, all_start_positions=[128, 361, 594], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 100,
#     Block(token_count=105, start_position=269, end_position=271, all_start_positions=[305, 538, 774], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 101,
#     Block(token_count=44, start_position=357, end_position=360, all_start_positions=[47, 280, 513, 749], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 102,
#     Block(token_count=44, start_position=747, end_position=750, all_start_positions=[133, 366, 599, 835], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 103,
#     Block(token_count=44, start_position=799, end_position=802, all_start_positions=[189, 422, 655, 891], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 104,
#     Block(token_count=104, start_position=57, end_position=59, all_start_positions=[306, 539, 775], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 105,
#     Block(token_count=104, start_position=759, end_position=761, all_start_positions=[129, 362, 595], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 106,
#     Block(token_count=103, start_position=53, end_position=55, all_start_positions=[307, 540, 776], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 107,
#     Block(token_count=103, start_position=647, end_position=649, all_start_positions=[130, 363, 596], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 108,
#     Block(token_count=102, start_position=599, end_position=601, all_start_positions=[131, 364, 597], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 109,
#     Block(token_count=102, start_position=827, end_position=829, all_start_positions=[308, 541, 777], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 110,
#     Block(token_count=43, start_position=45, end_position=48, all_start_positions=[48, 281, 514, 750], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 111,
#     Block(token_count=43, start_position=875, end_position=878, all_start_positions=[190, 423, 656, 892], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 112,
#     Block(token_count=43, start_position=887, end_position=890, all_start_positions=[134, 367, 600, 836], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 113,
#     Block(token_count=101, start_position=361, end_position=363, all_start_positions=[132, 365, 598], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 114,
#     Block(token_count=101, start_position=719, end_position=721, all_start_positions=[309, 542, 778], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 115,
#     Block(token_count=100, start_position=421, end_position=423, all_start_positions=[310, 543, 779], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 116,
#     Block(token_count=100, start_position=747, end_position=749, all_start_positions=[133, 366, 599], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 117,
#     Block(token_count=42, start_position=301, end_position=304, all_start_positions=[191, 424, 657, 893], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 118,
#     Block(token_count=42, start_position=607, end_position=610, all_start_positions=[135, 368, 601, 837], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 119,
#     Block(token_count=42, start_position=659, end_position=662, all_start_positions=[49, 282, 515, 751], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 120,
#     Block(token_count=99, start_position=237, end_position=239, all_start_positions=[311, 544, 780], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 121,
#     Block(token_count=99, start_position=887, end_position=889, all_start_positions=[134, 367, 600], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 122,
#     Block(token_count=98, start_position=193, end_position=195, all_start_positions=[312, 545, 781], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 123,
#     Block(token_count=98, start_position=607, end_position=609, all_start_positions=[135, 368, 601], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 124,
#     Block(token_count=41, start_position=169, end_position=172, all_start_positions=[136, 369, 602, 838], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 125,
#     Block(token_count=41, start_position=405, end_position=408, all_start_positions=[192, 425, 658, 894], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 126,
#     Block(token_count=41, start_position=471, end_position=474, all_start_positions=[50, 283, 516, 752], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 127,
#     Block(token_count=97, start_position=85, end_position=87, all_start_positions=[313, 546, 782], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 128,
#     Block(token_count=97, start_position=169, end_position=171, all_start_positions=[136, 369, 602], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 129,
#     Block(token_count=96, start_position=3, end_position=5, all_start_positions=[137, 370, 603], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 130,
#     Block(token_count=96, start_position=811, end_position=813, all_start_positions=[314, 547, 783], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 131,
#     Block(token_count=95, start_position=8, end_position=10, all_start_positions=[315, 548, 784], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 132,
#     Block(token_count=95, start_position=20, end_position=22, all_start_positions=[138, 371, 604], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 133,
#     Block(token_count=40, start_position=3, end_position=6, all_start_positions=[137, 370, 603, 839], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 134,
#     Block(token_count=40, start_position=325, end_position=328, all_start_positions=[193, 426, 659, 895], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 135,
#     Block(token_count=40, start_position=434, end_position=437, all_start_positions=[51, 284, 517, 753], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 136,
#     Block(token_count=94, start_position=699, end_position=701, all_start_positions=[139, 372, 605], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 137,
#     Block(token_count=94, start_position=755, end_position=757, all_start_positions=[316, 549, 785], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 138,
#     Block(token_count=93, start_position=767, end_position=769, all_start_positions=[140, 373, 606], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 139,
#     Block(token_count=93, start_position=891, end_position=893, all_start_positions=[317, 550, 786], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 140,
#     Block(token_count=39, start_position=20, end_position=23, all_start_positions=[138, 371, 604, 840], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 141,
#     Block(token_count=39, start_position=24, end_position=27, all_start_positions=[194, 427, 660, 896], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 142,
#     Block(token_count=39, start_position=41, end_position=44, all_start_positions=[52, 285, 518, 754], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 143,
#     Block(token_count=92, start_position=117, end_position=119, all_start_positions=[318, 551, 787], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 144,
#     Block(token_count=92, start_position=843, end_position=845, all_start_positions=[141, 374, 607], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 145,
#     Block(token_count=91, start_position=261, end_position=263, all_start_positions=[319, 552, 788], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 146,
#     Block(token_count=91, start_position=409, end_position=411, all_start_positions=[142, 375, 608], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 147,
#     Block(token_count=38, start_position=177, end_position=180, all_start_positions=[195, 428, 661, 897], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 148,
#     Block(token_count=38, start_position=699, end_position=702, all_start_positions=[139, 372, 605, 841], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 149,
#     Block(token_count=38, start_position=899, end_position=902, all_start_positions=[53, 286, 519, 755], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 150,
#     Block(token_count=90, start_position=137, end_position=139, all_start_positions=[143, 376, 609], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 151,
#     Block(token_count=90, start_position=783, end_position=785, all_start_positions=[320, 553, 789], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 152,
#     Block(token_count=89, start_position=197, end_position=199, all_start_positions=[321, 554, 790], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 153,
#     Block(token_count=89, start_position=575, end_position=577, all_start_positions=[144, 377, 610], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 154,
#     Block(token_count=88, start_position=209, end_position=211, all_start_positions=[145, 378, 611], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 155,
#     Block(token_count=88, start_position=695, end_position=697, all_start_positions=[322, 555, 791], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 156,
#     Block(token_count=37, start_position=376, end_position=379, all_start_positions=[196, 429, 662, 898], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 157,
#     Block(token_count=37, start_position=623, end_position=626, all_start_positions=[54, 287, 520, 756], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 158,
#     Block(token_count=37, start_position=767, end_position=770, all_start_positions=[140, 373, 606, 842], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 159,
#     Block(token_count=87, start_position=763, end_position=765, all_start_positions=[323, 556, 792], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 160,
#     Block(token_count=87, start_position=927, end_position=929, all_start_positions=[146, 379, 612], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 161,
#     Block(token_count=86, start_position=281, end_position=283, all_start_positions=[147, 380, 613], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 162,
#     Block(token_count=86, start_position=329, end_position=331, all_start_positions=[324, 557, 793], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 163,
#     Block(token_count=36, start_position=515, end_position=518, all_start_positions=[197, 430, 663, 899], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 164,
#     Block(token_count=36, start_position=519, end_position=522, all_start_positions=[55, 288, 521, 757], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 165,
#     Block(token_count=36, start_position=843, end_position=846, all_start_positions=[141, 374, 607, 843], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 166,
#     Block(token_count=85, start_position=459, end_position=461, all_start_positions=[148, 381, 614], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 167,
#     Block(token_count=85, start_position=839, end_position=841, all_start_positions=[325, 558, 794], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 168,
#     Block(token_count=84, start_position=297, end_position=299, all_start_positions=[149, 382, 615], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 169,
#     Block(token_count=84, start_position=380, end_position=382, all_start_positions=[326, 559, 795], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 170,
#     Block(token_count=83, start_position=16, end_position=18, all_start_positions=[150, 383, 616], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 171,
#     Block(token_count=83, start_position=639, end_position=641, all_start_positions=[327, 560, 796], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 172,
#     Block(token_count=35, start_position=409, end_position=412, all_start_positions=[142, 375, 608, 844], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 173,
#     Block(token_count=35, start_position=619, end_position=622, all_start_positions=[198, 431, 664, 900], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 174,
#     Block(token_count=35, start_position=743, end_position=746, all_start_positions=[56, 289, 522, 758], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 175,
#     Block(token_count=82, start_position=265, end_position=267, all_start_positions=[328, 561, 797], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 176,
#     Block(token_count=82, start_position=631, end_position=633, all_start_positions=[151, 384, 617], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 177,
#     Block(token_count=81, start_position=595, end_position=597, all_start_positions=[152, 385, 618], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 178,
#     Block(token_count=81, start_position=787, end_position=789, all_start_positions=[329, 562, 798], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 179,
#     Block(token_count=34, start_position=137, end_position=140, all_start_positions=[143, 376, 609, 845], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 180,
#     Block(token_count=34, start_position=451, end_position=454, all_start_positions=[199, 432, 665, 901], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 181,
#     Block(token_count=34, start_position=839, end_position=842, all_start_positions=[92, 325, 558, 794], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 182,
#     Block(token_count=34, start_position=883, end_position=886, all_start_positions=[57, 290, 523, 759], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 183,
#     Block(token_count=80, start_position=189, end_position=191, all_start_positions=[153, 386, 619], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 184,
#     Block(token_count=80, start_position=559, end_position=561, all_start_positions=[330, 563, 799], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 185,
#     Block(token_count=79, start_position=253, end_position=255, all_start_positions=[331, 564, 800], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 186,
#     Block(token_count=79, start_position=687, end_position=689, all_start_positions=[154, 387, 620], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 187,
#     Block(token_count=33, start_position=49, end_position=52, all_start_positions=[200, 433, 666, 902], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 188,
#     Block(token_count=33, start_position=245, end_position=248, all_start_positions=[58, 291, 524, 760], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 189,
#     Block(token_count=33, start_position=380, end_position=383, all_start_positions=[93, 326, 559, 795], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 190,
#     Block(token_count=33, start_position=575, end_position=578, all_start_positions=[144, 377, 610, 846], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 191,
#     Block(token_count=78, start_position=547, end_position=549, all_start_positions=[155, 388, 621], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 192,
#     Block(token_count=78, start_position=603, end_position=605, all_start_positions=[332, 565, 801], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 193,
#     Block(token_count=77, start_position=165, end_position=167, all_start_positions=[156, 389, 622], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 194,
#     Block(token_count=77, start_position=349, end_position=351, all_start_positions=[333, 566, 802], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 195,
#     Block(token_count=76, start_position=153, end_position=155, all_start_positions=[334, 567, 803], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 196,
#     Block(token_count=76, start_position=426, end_position=428, all_start_positions=[157, 390, 623], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 197,
#     Block(token_count=32, start_position=37, end_position=40, all_start_positions=[0, 234, 467, 703], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 198,
#     Block(token_count=32, start_position=209, end_position=212, all_start_positions=[145, 378, 611, 847], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 199,
#     Block(token_count=32, start_position=487, end_position=490, all_start_positions=[59, 292, 525, 761], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 200,
#     Block(token_count=32, start_position=639, end_position=642, all_start_positions=[94, 327, 560, 796], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 201,
#     Block(token_count=32, start_position=847, end_position=850, all_start_positions=[201, 434, 667, 903], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 202,
#     Block(token_count=75, start_position=133, end_position=135, all_start_positions=[158, 391, 624], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 203,
#     Block(token_count=75, start_position=611, end_position=613, all_start_positions=[335, 568, 804], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 204,
#     Block(token_count=74, start_position=285, end_position=287, all_start_positions=[159, 392, 625], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 205,
#     Block(token_count=74, start_position=815, end_position=817, all_start_positions=[336, 569, 805], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 206,
#     Block(token_count=31, start_position=161, end_position=164, all_start_positions=[202, 435, 668, 904], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 207,
#     Block(token_count=31, start_position=265, end_position=268, all_start_positions=[95, 328, 561, 797], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 208,
#     Block(token_count=31, start_position=735, end_position=738, all_start_positions=[60, 293, 526, 762], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 209,
#     Block(token_count=31, start_position=895, end_position=898, all_start_positions=[1, 235, 468, 704], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 210,
#     Block(token_count=31, start_position=927, end_position=930, all_start_positions=[146, 379, 612, 848], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 211,
#     Block(token_count=73, start_position=201, end_position=203, all_start_positions=[337, 570, 806], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 212,
#     Block(token_count=73, start_position=273, end_position=275, all_start_positions=[160, 393, 626], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 213,
#     Block(token_count=72, start_position=463, end_position=465, all_start_positions=[338, 571, 807], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 214,
#     Block(token_count=72, start_position=635, end_position=637, all_start_positions=[161, 394, 627], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 215,
#     Block(token_count=30, start_position=185, end_position=188, all_start_positions=[203, 436, 669, 905], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 216,
#     Block(token_count=30, start_position=281, end_position=284, all_start_positions=[147, 380, 613, 849], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 217,
#     Block(token_count=30, start_position=401, end_position=404, all_start_positions=[2, 236, 469, 705], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 218,
#     Block(token_count=30, start_position=579, end_position=582, all_start_positions=[61, 294, 527, 763], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 219,
#     Block(token_count=30, start_position=787, end_position=790, all_start_positions=[96, 329, 562, 798], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 220,
#     Block(token_count=71, start_position=321, end_position=323, all_start_positions=[162, 395, 628], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 221,
#     Block(token_count=71, start_position=393, end_position=395, all_start_positions=[339, 572, 808], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 222,
#     Block(token_count=70, start_position=446, end_position=448, all_start_positions=[340, 573, 809], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 223,
#     Block(token_count=70, start_position=795, end_position=797, all_start_positions=[163, 396, 629], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 224,
#     Block(token_count=69, start_position=643, end_position=645, all_start_positions=[341, 574, 810], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 225,
#     Block(token_count=69, start_position=723, end_position=725, all_start_positions=[164, 397, 630], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 226,
#     Block(token_count=232, start_position=37, end_position=38, all_start_positions=[234, 467], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 227,
#     Block(token_count=29, start_position=69, end_position=72, all_start_positions=[62, 295, 528, 764], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 228,
#     Block(token_count=29, start_position=459, end_position=462, all_start_positions=[148, 381, 614, 850], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 229,
#     Block(token_count=29, start_position=559, end_position=562, all_start_positions=[97, 330, 563, 799], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 230,
#     Block(token_count=29, start_position=775, end_position=778, all_start_positions=[204, 437, 670, 906], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 231,
#     Block(token_count=29, start_position=791, end_position=794, all_start_positions=[3, 237, 470, 706], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 232,
#     Block(token_count=231, start_position=895, end_position=896, all_start_positions=[235, 468], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 233,
#     Block(token_count=230, start_position=401, end_position=402, all_start_positions=[236, 469], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 234,
#     Block(token_count=68, start_position=438, end_position=440, all_start_positions=[165, 398, 631], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 235,
#     Block(token_count=68, start_position=831, end_position=833, all_start_positions=[342, 575, 811], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 236,
#     Block(token_count=229, start_position=791, end_position=792, all_start_positions=[237, 470], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 237,
#     Block(token_count=228, start_position=715, end_position=716, all_start_positions=[238, 471], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 238,
#     Block(token_count=227, start_position=369, end_position=370, all_start_positions=[239, 472], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 239,
#     Block(token_count=67, start_position=129, end_position=131, all_start_positions=[343, 576, 812], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 240,
#     Block(token_count=67, start_position=205, end_position=207, all_start_positions=[166, 399, 632], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 241,
#     Block(token_count=226, start_position=491, end_position=492, all_start_positions=[240, 473], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 242,
#     Block(token_count=225, start_position=739, end_position=740, all_start_positions=[241, 474], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 243,
#     Block(token_count=28, start_position=97, end_position=100, all_start_positions=[63, 296, 529, 765], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 244,
#     Block(token_count=28, start_position=141, end_position=144, all_start_positions=[205, 438, 671, 907], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 245,
#     Block(token_count=28, start_position=253, end_position=256, all_start_positions=[98, 331, 564, 800], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 246,
#     Block(token_count=28, start_position=297, end_position=300, all_start_positions=[149, 382, 615, 851], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 247,
#     Block(token_count=224, start_position=627, end_position=628, all_start_positions=[242, 475], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 248,
#     Block(token_count=28, start_position=715, end_position=718, all_start_positions=[4, 238, 471, 707], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 249,
#     Block(token_count=223, start_position=871, end_position=872, all_start_positions=[243, 476], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 250,
#     Block(token_count=66, start_position=77, end_position=79, all_start_positions=[344, 577, 813], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 251,
#     Block(token_count=66, start_position=467, end_position=469, all_start_positions=[167, 400, 633], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 252,
#     Block(token_count=222, start_position=539, end_position=540, all_start_positions=[244, 477], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 253,
#     Block(token_count=221, start_position=675, end_position=676, all_start_positions=[245, 478], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 254,
#     Block(token_count=220, start_position=475, end_position=476, all_start_positions=[246, 479], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 255,
#     Block(token_count=65, start_position=397, end_position=399, all_start_positions=[168, 401, 634], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 256,
#     Block(token_count=65, start_position=651, end_position=653, all_start_positions=[345, 578, 814], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 257,
#     Block(token_count=219, start_position=563, end_position=564, all_start_positions=[247, 480], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 258,
#     Block(token_count=218, start_position=503, end_position=504, all_start_positions=[248, 481], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 259,
#     Block(token_count=217, start_position=217, end_position=218, all_start_positions=[249, 482], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 260,
#     Block(token_count=27, start_position=16, end_position=19, all_start_positions=[150, 383, 616, 852], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 261,
#     Block(token_count=64, start_position=241, end_position=243, all_start_positions=[346, 579, 815], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 262,
#     Block(token_count=27, start_position=369, end_position=372, all_start_positions=[5, 239, 472, 708], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 263,
#     Block(token_count=216, start_position=583, end_position=584, all_start_positions=[250, 483], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 264,
#     Block(token_count=27, start_position=603, end_position=606, all_start_positions=[99, 332, 565, 801], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 265,
#     Block(token_count=64, start_position=779, end_position=781, all_start_positions=[169, 402, 635], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 266,
#     Block(token_count=27, start_position=851, end_position=854, all_start_positions=[206, 439, 672, 908], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 267,
#     Block(token_count=27, start_position=911, end_position=914, all_start_positions=[64, 297, 530, 766], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 268,
#     Block(token_count=215, start_position=73, end_position=74, all_start_positions=[251, 484], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 269,
#     Block(token_count=214, start_position=101, end_position=102, all_start_positions=[252, 485], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 270,
#     Block(token_count=213, start_position=527, end_position=528, all_start_positions=[253, 486], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 271,
#     Block(token_count=63, start_position=181, end_position=183, all_start_positions=[170, 403, 636], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 272,
#     Block(token_count=63, start_position=309, end_position=311, all_start_positions=[347, 580, 816], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 273,
#     Block(token_count=212, start_position=483, end_position=484, all_start_positions=[254, 487], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 274,
#     Block(token_count=211, start_position=707, end_position=708, all_start_positions=[255, 488], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 275,
#     Block(token_count=210, start_position=293, end_position=294, all_start_positions=[256, 489], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 276,
#     Block(token_count=62, start_position=105, end_position=107, all_start_positions=[171, 404, 637], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 277,
#     Block(token_count=62, start_position=771, end_position=773, all_start_positions=[348, 581, 817], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 278,
#     Block(token_count=209, start_position=591, end_position=592, all_start_positions=[257, 490], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 279,
#     Block(token_count=26, start_position=337, end_position=340, all_start_positions=[65, 298, 531, 767], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 280,
#     Block(token_count=26, start_position=349, end_position=352, all_start_positions=[100, 333, 566, 802], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 281,
#     Block(token_count=26, start_position=491, end_position=494, all_start_positions=[6, 240, 473, 709], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 282,
#     Block(token_count=26, start_position=631, end_position=634, all_start_positions=[151, 384, 617, 853], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 283,
#     Block(token_count=26, start_position=819, end_position=822, all_start_positions=[207, 440, 673, 909], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 284,
#     Block(token_count=208, start_position=919, end_position=920, all_start_positions=[258, 491], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 285,
#     Block(token_count=207, start_position=671, end_position=672, all_start_positions=[259, 492], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 286,
#     Block(token_count=206, start_position=835, end_position=836, all_start_positions=[260, 493], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 287,
#     Block(token_count=61, start_position=113, end_position=115, all_start_positions=[172, 405, 638], witnesses={0, 1, 2}, witness_count=3, frequency=3)),
#   ( 288,
#     Block(token_count=61, start_position=807, end_position=809, all_start_positions=[349, 582, 818], witnesses={1, 2, 3}, witness_count=3, frequency=3)),
#   ( 289,
#     Block(token_count=205, start_position=385, end_position=386, all_start_positions=[261, 494], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 290,
#     Block(token_count=204, start_position=691, end_position=692, all_start_positions=[262, 495], witnesses={1, 2}, witness_count=2, frequency=2)),
#   ( 291,
# ...
#     Block(token_count=8, start_position=779, end_position=782, all_start_positions=[169, 402, 635, 871], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 492,
#     Block(token_count=8, start_position=919, end_position=922, all_start_positions=[24, 258, 491, 727], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 493,
#     Block(token_count=7, start_position=181, end_position=184, all_start_positions=[170, 403, 636, 872], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 494,
#     Block(token_count=7, start_position=571, end_position=574, all_start_positions=[119, 352, 585, 821], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 495,
#     Block(token_count=7, start_position=663, end_position=666, all_start_positions=[226, 459, 692, 928], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 496,
#     Block(token_count=7, start_position=671, end_position=674, all_start_positions=[25, 259, 492, 728], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 497,
#     Block(token_count=7, start_position=891, end_position=894, all_start_positions=[84, 317, 550, 786], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 498,
#     Block(token_count=6, start_position=105, end_position=108, all_start_positions=[171, 404, 637, 873], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 499,
#     Block(token_count=6, start_position=117, end_position=120, all_start_positions=[85, 318, 551, 787], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 500,
#     Block(token_count=6, start_position=173, end_position=176, all_start_positions=[227, 460, 693, 929], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 501,
#     Block(token_count=6, start_position=341, end_position=344, all_start_positions=[120, 353, 586, 822], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 502,
#     Block(token_count=6, start_position=835, end_position=838, all_start_positions=[26, 260, 493, 729], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 503,
#     Block(token_count=5, start_position=113, end_position=116, all_start_positions=[172, 405, 638, 874], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 504,
#     Block(token_count=5, start_position=149, end_position=152, all_start_positions=[121, 354, 587, 823], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 505,
#     Block(token_count=5, start_position=261, end_position=264, all_start_positions=[86, 319, 552, 788], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 506,
#     Block(token_count=5, start_position=385, end_position=388, all_start_positions=[27, 261, 494, 730], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 507,
#     Block(token_count=5, start_position=479, end_position=482, all_start_positions=[228, 461, 694, 930], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 508,
#     Block(token_count=4, start_position=65, end_position=68, all_start_positions=[173, 406, 639, 875], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 509,
#     Block(token_count=4, start_position=289, end_position=292, all_start_positions=[122, 355, 588, 824], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 510,
#     Block(token_count=4, start_position=615, end_position=618, all_start_positions=[229, 462, 695, 931], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 511,
#     Block(token_count=4, start_position=691, end_position=694, all_start_positions=[28, 262, 495, 731], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 512,
#     Block(token_count=4, start_position=783, end_position=786, all_start_positions=[87, 320, 553, 789], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 513,
#     Block(token_count=3, start_position=197, end_position=200, all_start_positions=[88, 321, 554, 790], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 514,
#     Block(token_count=3, start_position=353, end_position=356, all_start_positions=[230, 463, 696, 932], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 515,
#     Block(token_count=3, start_position=417, end_position=420, all_start_positions=[33, 266, 499, 735], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 516,
#     Block(token_count=3, start_position=495, end_position=498, all_start_positions=[174, 407, 640, 876], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 517,
#     Block(token_count=3, start_position=751, end_position=754, all_start_positions=[29, 263, 496, 732], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 518,
#     Block(token_count=3, start_position=823, end_position=826, all_start_positions=[123, 356, 589, 825], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 519,
#     Block(token_count=2, start_position=305, end_position=308, all_start_positions=[34, 267, 500, 736], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 520,
#     Block(token_count=2, start_position=317, end_position=320, all_start_positions=[30, 264, 497, 733], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 521,
#     Block(token_count=2, start_position=430, end_position=433, all_start_positions=[124, 357, 590, 826], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 522,
#     Block(token_count=2, start_position=535, end_position=538, all_start_positions=[231, 464, 697, 933], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 523,
#     Block(token_count=2, start_position=855, end_position=858, all_start_positions=[175, 408, 641, 877], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 524,
#     Block(token_count=1, start_position=32, end_position=35, all_start_positions=[125, 358, 591, 827], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 525,
#     Block(token_count=1, start_position=233, end_position=236, all_start_positions=[31, 265, 498, 734], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 526,
#     Block(token_count=1, start_position=277, end_position=280, all_start_positions=[35, 268, 501, 737], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 527,
#     Block(token_count=1, start_position=413, end_position=416, all_start_positions=[232, 465, 698, 934], witnesses={0, 1, 2, 3}, witness_count=4, frequency=4)),
#   ( 528,
#     Block(token_count=1, start_position=384, end_position=388, all_start_positions=[27, 126, 261, 494, 730], witnesses={0, 1, 2, 3}, witness_count=4, frequency=5)),
#   ( 529,
#     Block(token_count=3, start_position=201, end_position=208, all_start_positions=[104, 166, 337, 399, 570, 632, 806, 868], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 530,
#     Block(token_count=3, start_position=711, end_position=718, all_start_positions=[4, 39, 238, 272, 471, 505, 707, 741], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 531,
#     Block(token_count=2, start_position=337, end_position=344, all_start_positions=[65, 120, 298, 353, 531, 586, 767, 822], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 532,
#     Block(token_count=2, start_position=365, end_position=372, all_start_positions=[5, 40, 239, 273, 472, 506, 708, 742], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 533,
#     Block(token_count=2, start_position=463, end_position=470, all_start_positions=[105, 167, 338, 400, 571, 633, 807, 869], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 534,
#     Block(token_count=2, start_position=579, end_position=586, all_start_positions=[16, 61, 250, 294, 483, 527, 719, 763], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 535,
#     Block(token_count=2, start_position=695, end_position=702, all_start_positions=[89, 139, 322, 372, 555, 605, 791, 841], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 536,
#     Block(token_count=2, start_position=791, end_position=798, all_start_positions=[3, 163, 237, 396, 470, 629, 706, 865], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 537,
#     Block(token_count=2, start_position=911, end_position=918, all_start_positions=[64, 69, 297, 302, 530, 535, 766, 771], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 538,
#     Block(token_count=1, start_position=8, end_position=15, all_start_positions=[82, 128, 315, 361, 548, 594, 784, 830], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 539,
#     Block(token_count=1, start_position=45, end_position=52, all_start_positions=[48, 200, 281, 433, 514, 666, 750, 902], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 540,
#     Block(token_count=1, start_position=93, end_position=100, all_start_positions=[63, 224, 296, 457, 529, 690, 765, 926], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 541,
#     Block(token_count=1, start_position=105, end_position=112, all_start_positions=[42, 171, 275, 404, 508, 637, 744, 873], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 542,
#     Block(token_count=1, start_position=117, end_position=124, all_start_positions=[85, 225, 318, 458, 551, 691, 787, 927], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 543,
#     Block(token_count=1, start_position=217, end_position=224, all_start_positions=[15, 211, 249, 444, 482, 677, 718, 913], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 544,
#     Block(token_count=1, start_position=237, end_position=244, all_start_positions=[78, 113, 311, 346, 544, 579, 780, 815], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 545,
#     Block(token_count=1, start_position=269, end_position=276, all_start_positions=[72, 160, 305, 393, 538, 626, 774, 862], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 546,
#     Block(token_count=1, start_position=285, end_position=292, all_start_positions=[122, 159, 355, 392, 588, 625, 824, 861], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 547,
#     Block(token_count=1, start_position=313, end_position=320, all_start_positions=[30, 187, 264, 420, 497, 653, 733, 889], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 548,
#     Block(token_count=1, start_position=357, end_position=364, all_start_positions=[47, 132, 280, 365, 513, 598, 749, 834], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 549,
#     Block(token_count=1, start_position=393, end_position=400, all_start_positions=[106, 168, 339, 401, 572, 634, 808, 870], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 550,
#     Block(token_count=1, start_position=430, end_position=437, all_start_positions=[51, 124, 284, 357, 517, 590, 753, 826], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 551,
#     Block(token_count=1, start_position=438, end_position=445, all_start_positions=[165, 219, 398, 452, 631, 685, 867, 921], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 552,
#     Block(token_count=1, start_position=507, end_position=514, all_start_positions=[210, 222, 443, 455, 676, 688, 912, 924], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 553,
#     Block(token_count=1, start_position=515, end_position=522, all_start_positions=[55, 197, 288, 430, 521, 663, 757, 899], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 554,
#     Block(token_count=1, start_position=527, end_position=534, all_start_positions=[19, 43, 253, 276, 486, 509, 722, 745], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 555,
#     Block(token_count=1, start_position=663, end_position=670, all_start_positions=[216, 226, 449, 459, 682, 692, 918, 928], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 556,
#     Block(token_count=1, start_position=763, end_position=770, all_start_positions=[90, 140, 323, 373, 556, 606, 792, 842], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 557,
#     Block(token_count=1, start_position=839, end_position=846, all_start_positions=[92, 141, 325, 374, 558, 607, 794, 843], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 558,
#     Block(token_count=1, start_position=847, end_position=854, all_start_positions=[201, 206, 434, 439, 667, 672, 903, 908], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 559,
#     Block(token_count=1, start_position=867, end_position=874, all_start_positions=[9, 46, 243, 279, 476, 512, 712, 748], witnesses={0, 1, 2, 3}, witness_count=4, frequency=8)),
#   ( 560,
#     Block(token_count=2, start_position=483, end_position=494, all_start_positions=[6, 20, 59, 240, 254, 292, 473, 487, 525, 709, 723, 761], witnesses={0, 1, 2, 3}, witness_count=4, frequency=12)),
#   ( 561,
#     Block(token_count=1, start_position=373, end_position=383, all_start_positions=[93, 196, 326, 359, 429, 559, 592, 662, 795, 828, 898], witnesses={0, 1, 2, 3}, witness_count=4, frequency=11)),
#   ( 562,
#     Block(token_count=1, start_position=133, end_position=144, all_start_positions=[143, 158, 205, 376, 391, 438, 609, 624, 671, 845, 860, 907], witnesses={0, 1, 2, 3}, witness_count=4, frequency=12)),
#   ( 563,
#     Block(token_count=1, start_position=145, end_position=156, all_start_positions=[66, 101, 121, 299, 334, 354, 532, 567, 587, 768, 803, 823], witnesses={0, 1, 2, 3}, witness_count=4, frequency=12)),
#   ( 564,
#     Block(token_count=1, start_position=337, end_position=348, all_start_positions=[65, 70, 120, 298, 303, 353, 531, 536, 586, 767, 772, 822], witnesses={0, 1, 2, 3}, witness_count=4, frequency=12)),
#   ( 565,
#     Block(token_count=1, start_position=535, end_position=546, all_start_positions=[10, 45, 231, 244, 278, 464, 477, 511, 697, 713, 747, 933], witnesses={0, 1, 2, 3}, witness_count=4, frequency=12)),
#   ( 566,
#     Block(token_count=1, start_position=559, end_position=570, all_start_positions=[13, 97, 221, 247, 330, 454, 480, 563, 687, 716, 799, 923], witnesses={0, 1, 2, 3}, witness_count=4, frequency=12)),
#   ( 567,
#     Block(token_count=1, start_position=891, end_position=902, all_start_positions=[1, 53, 84, 235, 286, 317, 468, 519, 550, 704, 755, 786], witnesses={0, 1, 2, 3}, witness_count=4, frequency=12)),
#   ( 568,
#     Block(token_count=1, start_position=815, end_position=830, all_start_positions=[75, 103, 123, 207, 308, 336, 356, 440, 541, 569, 589, 673, 777, 805, 825, 909], witnesses={0, 1, 2, 3}, witness_count=4, frequency=16)),
#   ( 569,
#     Block(token_count=1, start_position=911, end_position=926, all_start_positions=[24, 64, 69, 117, 258, 297, 302, 350, 491, 530, 535, 583, 727, 766, 771, 819], witnesses={0, 1, 2, 3}, witness_count=4, frequency=16)),
#   ( 570,
#     Block(token_count=1, start_position=687, end_position=705, all_start_positions=[28, 89, 139, 154, 177, 262, 322, 372, 387, 410, 495, 555, 605, 620, 643, 731, 791, 841, 856], witnesses={0, 1, 2, 3}, witness_count=4, frequency=19)),
#   ( 571,
#     Block(token_count=1, start_position=69, end_position=92, all_start_positions=[17, 62, 68, 80, 111, 176, 251, 295, 301, 313, 344, 409, 484, 528, 534, 546, 577, 642, 720, 764, 770, 782, 813, 878], witnesses={0, 1, 2, 3}, witness_count=4, frequency=24)),
#   ( 572,
#     Block(token_count=1, start_position=775, end_position=810, all_start_positions=[3, 87, 96, 116, 163, 169, 184, 189, 204, 237, 320, 329, 349, 396, 402, 417, 422, 437, 470, 553, 562, 582, 629, 635, 650, 655, 670, 706, 789, 798, 818, 865, 871, 886, 891, 906], witnesses={0, 1, 2, 3}, witness_count=4, frequency=36)),
#   ( 573,
#     Block(token_count=1, start_position=707, end_position=750, all_start_positions=[4, 7, 21, 39, 56, 60, 76, 118, 133, 164, 179, 238, 241, 255, 272, 289, 293, 309, 351, 366, 397, 412, 471, 474, 488, 505, 522, 526, 542, 584, 599, 630, 645, 707, 710, 724, 741, 758, 762, 778, 820, 835, 866, 881], witnesses={0, 1, 2, 3}, witness_count=4, frequency=44)),
#   ( 574,
#     Block(token_count=1, start_position=450, end_position=498, all_start_positions=[6, 12, 20, 41, 50, 59, 105, 148, 167, 174, 199, 228, 240, 246, 254, 274, 283, 292, 338, 381, 400, 407, 432, 461, 473, 479, 487, 507, 516, 525, 571, 614, 633, 640, 665, 694, 701, 709, 715, 723, 743, 752, 761, 807, 850, 869, 876, 901, 930], witnesses={0, 1, 2, 3}, witness_count=4, frequency=49))]

# %%
# for index,block in enumerate(prioritized_blocks):
#     first_token = block.all_start_positions[0]
#     first_five_tokens = token_array[first_token: first_token + 4] # wrong with token_count < 5
#     witnesses = block.witnesses
#     token_count = block.token_count
#     if 'when' in first_five_tokens:
#         pp.pprint((index, first_five_tokens, witnesses, token_count))

# %%
# for index,value in enumerate(token_array):
#     if value == 'when':
#         print(token_membership_array[index], token_array[index - 2 : index + 3])

# %% [markdown]
# # Start here
#
# 1. Add block identifier to VG token when token is created:  store 1) block id, 2) offset within block. This won't track all blocks associated with the token, but it will record the block we were processing when the token was first created.
# 1. Create hyperedges that group *sibling* (*transposition*) VG nodes as they're created. Decide what to do about them later. They'll tell us which nodes are related, but not necessarily which specifically are transposed with which others.
#
# # The offset within a block is calculated in exact positions in line 17
# We would need to record the relative offset next to the block identifier, so the exact position - the start position.
#
# # Priority
#
# 1. We already prioritize blocks
# 1. We can also prioritize tokens with blocks

# %%
# import itertools
# groups = []
# unique_keys = []
# result = itertools.groupby(vg.keys(), key=lambda x: (x.block_id, x.token_offset))
# # pp.pprint(list(result))
# for k, g in result:
#     if k != (None, None):
#             groups.append(list(g))
#             unique_keys.append(k)
# pp.pprint(list(zip(unique_keys, groups)))

# for vg_node in vg:
#     if vg_node.block_id:
#         print(vg_node.block_id, vg_node.token_offset, vg_node)

# groups = []
# uniquekeys = []
# data = sorted(data, key=keyfunc)
# for k, g in groupby(data, keyfunc):
#     groups.append(list(g))      # Store group iterator as a list
#     uniquekeys.append(k)

# %%
# Sort vg by block_id and first token offset
# Return block_id, first token offset, and token strings with numbers
# vg_nodes = sorted([(k.block_id, k.token_offset, k) for k in vg.keys() if k.block_id != None], key=lambda x: (x[0], x[1]))
# for vg_node in vg_nodes:
#     key = vg_node[2]
#     print((vg_node[0:2], [token_array[key[i]] for i in ['w0', 'w1', 'w2', 'w3'] if i in key]))

# %%
# Low-priority blocks are more likely to be transposed
# Blocks appear to be okay; check how we add them to the variant graph
# for pb in prioritized_blocks:
#     print(set([token_array[sp] for sp in pb.all_start_positions]))

# %%
# pp.pprint(list(enumerate(token_array)))

# %%
# tuple_to_token_map

# %%
# len(prioritized_blocks)

# %%
# placed_tokens
